# %% [markdown]
# <a href="https://colab.research.google.com/github/Arun9438/assignment/blob/main/Untitled13.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ## 1. What is the difference between interpreted and compiled languages?
# Answer:
# Interpreted languages execute code line by line using an interpreter (e.g., Python), making debugging easier. Compiled languages convert the entire program into machine code before execution (e.g., C, C++), resulting in faster execution.
# ## 2. What is exception handling in Python?
# Answer:
# Exception handling is a mechanism to handle runtime errors using try, except, else, and finally blocks so that the program does not crash unexpectedly.
# ## 3. What is the purpose of the finally block?
# Answer:
# The finally block always executes whether an exception occurs or not. It is mainly used for cleanup actions like closing files or releasing resources.
# ## 4. What is logging in Python?
# Answer:
# Logging is used to record messages that describe program execution, errors, warnings, and debugging information using the logging module.
# ## 5. Significance of the __del__ method in Python?
# Answer:
# The __del__ method is a destructor that is called when an object is destroyed. It helps release resources such as files or network connections.
# ## 6. Difference between import and from … import?
# Answer:
# import module imports the entire module
# from module import item imports specific components
# ## 7. How can you handle multiple exceptions in Python?
# Answer:
# Using multiple except blocks or a tuple of exceptions.
# ## 8. Purpose of the with statement in file handling?
# Answer:
# The with statement automatically closes the file after use, even if an exception occurs.
# ## 9. Difference between multithreading and multiprocessing?
# Answer:
# Multithreading: Multiple threads share the same memory space
# Multiprocessing: Multiple processes run independently with separate memory
# ## 10. Advantages of using logging?
# Answer:
# Better debugging
# Persistent records
# Adjustable verbosity
# Useful in production environments
# ## 11. What is memory management in Python?
# Answer:
# Memory management refers to how Python allocates and deallocates memory automatically using reference counting and garbage collection.
# ## 12. Basic steps involved in exception handling?
# Answer:
# Place risky code inside try
# Handle errors using except
# Optional else if no exception
# finally for cleanup
# ## 13. Why is memory management important?
# Answer:
# Efficient memory management prevents memory leaks and improves performance and stability of applications.
# ## 14. Role of try and except?
# Answer:
# try contains code that may cause an error, and except handles that error gracefully.
# ## 15. How does Python’s garbage collection work?
# Answer:
# Python uses reference counting and cyclic garbage collection to free unused memory automatically.
# ## 16. Purpose of the else block in exception handling?
# Answer:
# The else block runs when no exception occurs in the try block.
# ## 17. Common logging levels in Python?
# Answer:
# DEBUG
# INFO
# WARNING
# ERROR
# CRITICAL
# ## 18. Difference between os.fork() and multiprocessing?
# Answer:
# os.fork() creates a child process in Unix systems, while multiprocessing is platform-independent and safer.
# ## 19. Importance of closing a file?
# Answer:
# Closing a file releases system resources and ensures data is properly saved.
# ## 20. Difference between file.read() and file.readline()?
# Answer:
# read() reads entire file
# readline() reads one line at a time
# ## 21. Purpose of the logging module?
#
# Answer:
# The logging module records runtime events, errors, and application flow details.
# ## 22. Use of os module in file handling?
# Answer:
# It provides functions to interact with the operating system, such as file paths and directory handling.
# ## 23. Challenges in memory management?
# Answer:
# Memory leaks
# Circular references
# High memory usage
# ## 24. How do you raise an exception manually?
# Answer:
# Using the raise keyword.
# ## 25. Why use multithreading?
# Answer:
# Multithreading improves performance in I/O-bound applications like file handling and network operations.

# %% [markdown]
# ## 🔹 Practical Questions
# 1. Open a file for writing and write a string

# %%
with open("example.txt", "w") as f:
    f.write("This is a test string.\n")
print("Content written to example.txt")
# Out:
# Content written to example.txt

# %% [markdown]
# ## 2. Read file contents line by line

# %%
with open("example.txt", "r") as f:
    for line in f:
        print(line.strip())
# Out:
# This is a test string.

# %% [markdown]
# ## 3. Handle file not found error

# %%
try:
    with open("missing.txt", "r") as f:
        print(f.read())
except FileNotFoundError:
    print("File not found")
# Out:
# File not found

# %% [markdown]
# ## 4. Copy content from one file to another

# %%
# Create source.txt with some content for demonstration
with open("source.txt", "w") as f:
    f.write("This is the content of the source file.\n")
    f.write("Second line of content.")

# Now copy content from source.txt to dest.txt
with open("source.txt", "r") as src, open("dest.txt", "w") as dst:
    dst.write(src.read())

print("Content copied from source.txt to dest.txt")
# Out:
# Content copied from source.txt to dest.txt

# %% [markdown]
# ## 5. Handle division by zero

# %%
try:
    x = 10 / 0
except ZeroDivisionError:
    print("Division by zero error")

# %% [markdown]
# ## 6. Log error on division by zero

# %%
import logging

logging.basicConfig(filename="error.log", level=logging.ERROR)

try:
    x = 10 / 0
except ZeroDivisionError:
    logging.error("Division by zero occurred")

# %% [markdown]
# ## 7. Log INFO, WARNING, ERROR

# %%
import logging

logging.basicConfig(level=logging.INFO)
logging.info("Info message")
logging.warning("Warning message")
logging.error("Error message")
# Out:
# WARNING:root:Warning message
# ERROR:root:Error message

# %% [markdown]
# ## 8. Handle file opening error

# %%
try:
    f = open("abc.txt", "r")
except IOError:
    print("File error occurred")
# Out:
# File error occurred

# %% [markdown]
# 9. Read file line by line into a list

# %%
with open("example.txt", "r") as f:
    lines = f.readlines()
print(lines)
# Out:
# ['This is a test string.\n']

# %% [markdown]
# 10. Append data to a file

# %%
with open("example.txt", "a") as f:
    f.write("\nAppended line")

# %% [markdown]
# 11. Handle missing dictionary key

# %%
data = {"a": 1}

try:
    print(data["b"])
except KeyError:
    print("Key not found")
# Out:
# Key not found

# %% [markdown]
# 12. Multiple except blocks

# %%
try:
    x = int("abc")
except ValueError:
    print("Value Error")
except TypeError:
    print("Type Error")
# Out:
# Value Error

# %% [markdown]
# 13. Check if file exists

# %%
import os

if os.path.exists("example.txt"):
    print("File exists")
# Out:
# File exists

# %% [markdown]
# 14. Log info and error messages

# %%
import logging

logging.basicConfig(filename="app.log", level=logging.INFO)
logging.info("Program started")
logging.error("Sample error")
# Out:
# ERROR:root:Sample error

# %% [markdown]
# 15. Handle empty file

# %%
with open("example.txt", "r") as f:
    content = f.read()
    if not content:
        print("File is empty")

# %% [markdown]
# 16. Memory profiling demonstration

# %%
import sys

a = [1, 2, 3]
print(sys.getsizeof(a))
# Out:
# 88

# %% [markdown]
# 17. Write list of numbers to file

# %%
nums = [1, 2, 3, 4, 5]

with open("numbers.txt", "w") as f:
    for n in nums:
        f.write(str(n) + "\n")

# %% [markdown]
# 18. Logging with rotation

# %%
from logging.handlers import RotatingFileHandler
import logging

handler = RotatingFileHandler("rotate.log", maxBytes=1000000, backupCount=3)
logging.basicConfig(handlers=[handler], level=logging.INFO)
logging.info("Log rotation example")

# %% [markdown]
# 19. Handle IndexError and KeyError

# %%
data = [1, 2]
dic = {"a": 1}

try:
    print(data[5])
    print(dic["b"])
except IndexError:
    print("Index error")
except KeyError:
    print("Key error")
# Out:
# Index error

# %% [markdown]
# 20. Use context manager to read file

# %%
with open("example.txt", "r") as f:
    print(f.read())
# Out:
# This is a test string.
#
# Appended line

# %% [markdown]
# 21. Count occurrences of a word

# %%
with open("example.txt", "r") as f:
    text = f.read()
    print(text.count("Python"))
# Out:
# 0

# %% [markdown]
# 22. Check if file is empty

# %%
import os

if os.path.getsize("example.txt") == 0:
    print("File is empty")

# %% [markdown]
# 23. Log error during file handling

# %%
import logging

logging.basicConfig(filename="file_error.log", level=logging.ERROR)

try:
    open("no_file.txt", "r")
except Exception as e:
    logging.error(e)
# Out:
# ERROR:root:[Errno 2] No such file or directory: 'no_file.txt'
